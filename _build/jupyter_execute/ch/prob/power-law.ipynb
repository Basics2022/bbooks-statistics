# %% [markdown]
# (prob:rare-events:power-law)=
# # Power-law distribution
#
# Power-law distributions are an extreme case of heavy-tailed distribution. As an example, the tail of a power-law distribution decays as $x^\alpha$, with $\alpha < 0$, for $x \rightarrow +\infty$.
